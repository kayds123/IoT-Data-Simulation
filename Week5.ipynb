# %%
import pandas as pd


# Load IoT sensor data from CSV (Generated in Homework 1)
df = pd.read_csv("healthcare_data.csv")


# Display the first few rows
print(df.head())
# Out:
#                     timestamp patient_id  heart_rate blood_pressure  \
# 0  2025-06-24 08:29:33.318872     PAT573          98         105/75
# 1  2025-06-24 07:41:33.319010     PAT472          93         134/87
# 2  2025-06-24 01:32:33.319742     PAT368          81         108/62
# 3  2025-06-24 10:11:33.319830     PAT255          91         105/76
# 4  2025-06-24 02:53:33.319879     PAT467          78         126/81
#
#    oxygen_level  body_temp
# 0            95       36.6
# 1            98       36.5
# 2            98       36.5
# 3            97       37.4
# 4            98       36.4

# %%
from web3 import Web3


# Connect to local blockchain
ganache_url = "http://127.0.0.1:7545"
web3 = Web3(Web3.HTTPProvider(ganache_url))


# Verify connection
if web3.is_connected():
    print("✅ Connected to Ganache successfully!")
else:
    print("❌ Connection failed. Ensure Ganache is running.")
# Out:
# ✅ Connected to Ganache successfully!

# %%
# Replace with actual contract address from Remix
contract_address = "0xdC40C6d7fA6afd20c130634AF818418016077018"


# Paste the ABI from Remix
abi = [
	{
		"inputs": [],
		"stateMutability": "nonpayable",
		"type": "constructor"
	},
	{
		"anonymous": False,
		"inputs": [
			{
				"indexed": False,
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "patientId",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "metricType",
				"type": "string"
			},
			{
				"indexed": False,
				"internalType": "string",
				"name": "metricValue",
				"type": "string"
			}
		],
		"name": "DataStored",
		"type": "event"
	},
	{
		"inputs": [
			{
				"internalType": "string",
				"name": "_patientId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_metricType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "_metricValue",
				"type": "string"
			}
		],
		"name": "storeData",
		"outputs": [],
		"stateMutability": "nonpayable",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"name": "dataRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "timestamp",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "patientId",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "metricType",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "metricValue",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [
			{
				"internalType": "uint256",
				"name": "index",
				"type": "uint256"
			}
		],
		"name": "getRecord",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			},
			{
				"internalType": "string",
				"name": "",
				"type": "string"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "getTotalRecords",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "MAX_ENTRIES",
		"outputs": [
			{
				"internalType": "uint256",
				"name": "",
				"type": "uint256"
			}
		],
		"stateMutability": "view",
		"type": "function"
	},
	{
		"inputs": [],
		"name": "owner",
		"outputs": [
			{
				"internalType": "address",
				"name": "",
				"type": "address"
			}
		],
		"stateMutability": "view",
		"type": "function"
	}
]  

# Replace with your contract ABI


# Load the smart contract
contract = web3.eth.contract(address=contract_address, abi=abi)


# Set default sender (first account from Ganache)
web3.eth.default_account = web3.eth.accounts[0]


print(f"✅ Connected to Smart Contract at {contract_address}")
# Out:
# ✅ Connected to Smart Contract at 0xdC40C6d7fA6afd20c130634AF818418016077018

# %%
def send_iot_data(device_id, data_type, data_value):
    """Send a single IoT data point to the smart contract."""
    txn = contract.functions.storeData(device_id, data_type, data_value).transact({
        'from': web3.eth.default_account,
        'gas': 3000000
    })
    receipt = web3.eth.wait_for_transaction_receipt(txn)
    print(f"✅ Data Stored: {data_type} - {data_value}, Txn Hash: {receipt.transactionHash.hex()}")

# %%
import time

for _, row in df.iterrows():
    device_id = str(row["patient_id"])

    send_iot_data(device_id, "heart_rate", str(row["heart_rate"]))
    send_iot_data(device_id, "blood_pressure", str(row["blood_pressure"]))
    send_iot_data(device_id, "oxygen_level", str(row["oxygen_level"]))
    send_iot_data(device_id, "body_temp", str(row["body_temp"]))

    time.sleep(1)  # Prevent overloading the network
# Out:
# ✅ Data Stored: heart_rate - 98, Txn Hash: b9442656cd6ebad6332dc58a1f54af2961ad360f5c2cad0b90e30b699656f027
# ✅ Data Stored: blood_pressure - 105/75, Txn Hash: b99d5460cd61caa9de320c5563ee69315867aaea9940e34e284c87a8fa3df14c
# ✅ Data Stored: oxygen_level - 95, Txn Hash: fd361176e015847d5346fbd3da64777e160e66b9e07d1c5a5b961885c31e2b92
# ✅ Data Stored: body_temp - 36.6, Txn Hash: ea543995780a4fa3d98bbae397591a2df983104756aa210128a65a5339dac82c
# ✅ Data Stored: heart_rate - 93, Txn Hash: c3ca54fbdf7c1f76665c3cc36d2619aff30b584f60c3948a210000ea700a1ba5
# ✅ Data Stored: blood_pressure - 134/87, Txn Hash: 7cb49e4d87caf402e943d1fc996837c58c3a12a28f44c912280f7d4200149c0b
# ✅ Data Stored: oxygen_level - 98, Txn Hash: 69310ed66dee5fe545cc2d50298adc90768e01fb0aabe0dc71a8ec9f737a54c8
# ✅ Data Stored: body_temp - 36.5, Txn Hash: b082990039fb03b11dedfbc998faa6da669fea696ab91c001212d4400e3af738
# ✅ Data Stored: heart_rate - 81, Txn Hash: 4bb7b5082da509f430cdabb624e189fe92d1ba3c34bd45bc4bff1975204f3731
# ✅ Data Stored: blood_pressure - 108/62, Txn Hash: ef04b94f02af57b9651f90a8568491352c4af422587b261e20a8bc5f2636eb23
# ✅ Data Stored: oxygen_level - 98, Txn Hash: 8c92ff365039e1d366c2ef90d2856dbb6adfd9d38647ea9818617a4f611b3ed1
# ✅ Data Stored: body_temp - 36.5, Txn Hash: f696b9cb2aa5eadd090fc9b7746077b428ae754afb236e7d49233cade20ffa80
# ✅ Data Stored: heart_rate - 91, Txn Hash: 9607f72e43d8c99d71ae1a3912093a9d817b12e9085d30cb3eae94022b8024a5
# ✅ Data Stored: blood_pressure - 105/76, Txn Hash: a04193714a5e79128ff048e9bc3c889e7f66184278d28346cf02b4ad3a2efd94
# ✅ Data Stored: oxygen_level - 97, Txn Hash: de04cf64e920a569302560c5586b850afa2c216b5b289d850edce8c2042a254d
# ✅ Data Stored: body_temp - 37.4, Txn Hash: d8c1c3c91e1d447a3e4d456f97d511f29b70ce0872422c5130586c979b92c8ff
# ✅ Data Stored: heart_rate - 78, Txn Hash: 7d589d5e4c50b0ab321d2672529a92b3ee31b9eb5aaee6bd946d951bb1777e27
# ✅ Data Stored: blood_pressure - 126/81, Txn Hash: 8ab55356418ca45ac2761502688aa32f2066b0d2722c6bae500c4b5d78caaafa
# ✅ Data Stored: heart_rate - 86, Txn Hash: f51728e15804000b9af4bcb3b037a4a5397c0e727fc2958ba888383349bad7f3
# ✅ Data Stored: blood_pressure - 138/71, Txn Hash: 2a377aaae01aacaa9a62d8caf04456f127b63e16806e3c7fd98aa574a2de10e5
# ✅ Data Stored: oxygen_level - 98, Txn Hash: 99131c3a2729a8b936c52f0cbbabc86584e1ae2dedbda12b8e2ade80f1527096
# ✅ Data Stored: body_temp - 36.6, Txn Hash: a17698a292b34eb071cea7a37ec6dad077b389eb893555ab9198ab5a56a2b30b
# ✅ Data Stored: heart_rate - 98, Txn Hash: 2c8af908b8b2c76499c777ad25ffec3866b71ecb818c03cd1c0a8272cabff6d9
# ✅ Data Stored: blood_pressure - 136/87, Txn Hash: 7602ee5511a467578a74f0f1076b9f3f4a47926f078a0d1d85b8978e690956d2
# ✅ Data Stored: oxygen_level - 96, Txn Hash: fa95b2bdc63c8e713a6456855a694c5b8e4d813911c7ac72be072a03a13fd3e1
# ✅ Data Stored: body_temp - 37.4, Txn Hash: 80dc576dd8b06494b9757da79f284ad9c731d500c7c3d9fe0eb9edb805cb8fe2
# ✅ Data Stored: heart_rate - 95, Txn Hash: 476a049efa0d87256762e747182810cd04448ccaa2db3e0d60361aa91a6c54b6
# ✅ Data Stored: blood_pressure - 131/78, Txn Hash: 90e861ca78318fc5d6544de00ef5c272959f2a68788517298149121298a0e3fb
# ✅ Data Stored: oxygen_level - 95, Txn Hash: d2c8034a681b9c67da2c551b6c617ec0560f1db842a385ded763524f31f704df
# ✅ Data Stored: body_temp - 37.5, Txn Hash: c424d8950696861fbbf4bf8724cad9bcc448eed97c948f8eeaac21a151e5499e
# ✅ Data Stored: heart_rate - 68, Txn Hash: 8d871bd13ece07ce648505a05ab421333c192093e946386158e37fab9cabb31c
# ✅ Data Stored: blood_pressure - 106/60, Txn Hash: 59d32c4b3893bbedb9a4dac05d45ed7e9b57cf78ce63ad05e58ec376247dca30
# ✅ Data Stored: oxygen_level - 99, Txn Hash: 3cab5fd9e5ef83a8e8ebd89323e91dd4fdaa32d773565b8f4718c7f3def71a5b
# ✅ Data Stored: body_temp - 37.7, Txn Hash: f6f9b8fc47204e103a4630525614a2de12c7df2926831167cef269e5a5c8748c
# ✅ Data Stored: heart_rate - 86, Txn Hash: e58f009f81a90d1c61bf444ff8a323bdad330e627c9e57a3b85fdb3afb0f200a
# ✅ Data Stored: blood_pressure - 133/81, Txn Hash: ef21e0cfb855f08469547df1febc25564edc38e3420c0c2d670edffe49cc1743
# ✅ Data Stored: oxygen_level - 98, Txn Hash: 9eee76035726f9bd3168d9a14548bc8b03b93977d3a6a7adbbf3a7e18f513e30
# ✅ Data Stored: body_temp - 36.6, Txn Hash: 1e679e94800a6c711c4843650699ccc5f79b768c4c197ca3ba24e50692c645ea
# ---------------------------------------------------------------------------
# Web3RPCError                              Traceback (most recent call last)
# Cell In[13], line 6
#       3 for _, row in df.iterrows():
#       4     device_id = str(row["patient_id"])
# ----> 6     send_iot_data(device_id, "heart_rate", str(row["heart_rate"]))
#       7     send_iot_data(device_id, "blood_pressure", str(row["blood_pressure"]))
#       8     send_iot_data(device_id, "oxygen_level", str(row["oxygen_level"]))
#
# Cell In[12], line 3, in send_iot_data(device_id, data_type, data_value)
#       1 def send_iot_data(device_id, data_type, data_value):
#       2     """Send a single IoT data point to the smart contract."""
# ----> 3     txn = contract.functions.storeData(device_id, data_type, data_value).transact({
#       4         'from': web3.eth.default_account,
#       5         'gas': 3000000
#       6     })
#       7     receipt = web3.eth.wait_for_transaction_receipt(txn)
#       8     print(f"✅ Data Stored: {data_type} - {data_value}, Txn Hash: {receipt.transactionHash.hex()}")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/contract/contract.py:311, in ContractFunction.transact(self, transaction)
#     308 setup_transaction = self._transact(transaction)
#     309 abi_element_identifier = abi_to_signature(self.abi)
# --> 311 return transact_with_contract_function(
#     312     self.address,
#     313     self.w3,
#     314     abi_element_identifier,
#     315     setup_transaction,
#     316     self.contract_abi,
#     317     self.abi,
#     318     *self.args or (),
#     319     **self.kwargs or {},
#     320 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/contract/utils.py:265, in transact_with_contract_function(address, w3, abi_element_identifier, transaction, contract_abi, fn_abi, *args, **kwargs)
#     250 """
#     251 Helper function for interacting with a contract function by sending a
#     252 transaction.
#     253 """
#     254 transact_transaction = prepare_transaction(
#     255     address,
#     256     w3,
#    (...)    262     fn_kwargs=kwargs,
#     263 )
# --> 265 txn_hash = w3.eth.send_transaction(transact_transaction)
#     266 return txn_hash
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/eth/eth.py:387, in Eth.send_transaction(self, transaction)
#     386 def send_transaction(self, transaction: TxParams) -> HexBytes:
# --> 387     return self._send_transaction(transaction)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/module.py:112, in retrieve_blocking_method_call_fn.<locals>.caller(*args, **kwargs)
#     105     return LogFilter(eth_module=module, filter_id=err.filter_id)
#     107 (
#     108     result_formatters,
#     109     error_formatters,
#     110     null_result_formatters,
#     111 ) = response_formatters
# --> 112 result = w3.manager.request_blocking(
#     113     method_str, params, error_formatters, null_result_formatters
#     114 )
#     115 return apply_result_formatters(result_formatters, result)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/manager.py:232, in RequestManager.request_blocking(self, method, params, error_formatters, null_result_formatters)
#     228 """
#     229 Make a synchronous request using the provider
#     230 """
#     231 response = self._make_request(method, params)
# --> 232 return self.formatted_response(
#     233     response, params, error_formatters, null_result_formatters
#     234 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/manager.py:198, in RequestManager.formatted_response(self, response, params, error_formatters, null_result_formatters)
#     184 def formatted_response(
#     185     self,
#     186     response: RPCResponse,
#    (...)    189     null_result_formatters: Optional[Callable[..., Any]] = None,
#     190 ) -> Any:
#     191     is_subscription_response = (
#     192         response.get("method") == "eth_subscription"
#     193         and response.get("params") is not None
#     194         and response["params"].get("subscription") is not None
#     195         and response["params"].get("result") is not None
#     196     )
# --> 198     validate_rpc_response_and_raise_if_error(
#     199         response,
#     200         error_formatters,
#     201         is_subscription_response=is_subscription_response,
#     202         logger=self.logger,
#     203         params=params,
#     204     )
#     206     # format results
#     207     if "result" in response:
#     208         # Null values for result should apply null_result_formatters
#     209         # Skip when result not present in the response (fallback to False)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/web3/_utils/validation.py:401, in validate_rpc_response_and_raise_if_error(response, error_formatters, is_subscription_response, logger, params)
#     398     if logger is not None:
#     399         logger.debug("RPC error response: %s", response)
# --> 401     raise web3_rpc_error
#     403 elif "result" not in response and not is_subscription_response:
#     404     _raise_bad_response_format(response)
#
# Web3RPCError: {'message': 'VM Exception while processing transaction: revert Storage limit reached', 'stack': 'RuntimeError: VM Exception while processing transaction: revert Storage limit reached\n    at EIP1559FeeMarketTransaction.fillFromResult (/Applications/Ganache.app/Contents/Resources/static/node/node_modules/ganache/dist/node/1.js:2:12745)\n    at Miner.<anonymous> (/Applications/Ganache.app/Contents/Resources/static/node/node_modules/ganache/dist/node/1.js:2:36703)\n    at async Miner.<anonymous> (/Applications/Ganache.app/Contents/Resources/static/node/node_modules/ganache/dist/node/1.js:2:35116)\n    at async Miner.mine (/Applications/Ganache.app/Contents/Resources/static/node/node_modules/ganache/dist/node/1.js:2:39680)\n    at async Blockchain.mine (/Applications/Ganache.app/Contents/Resources/static/node/node_modules/ganache/dist/node/1.js:2:60063)\n    at async Promise.all (index 0)\n    at async TransactionPool.emit (/Applications/Ganache.app/Contents/Resources/static/node/node_modules/ganache/node_modules/emittery/index.js:303:3)', 'code': -32000, 'name': 'RuntimeError', 'data': {'hash': '0x925a4bb6aaa0bc3485e4e48558dfaa370d02c2985f62955d26c0f47cfd56cc2f', 'programCounter': 1714, 'result': '0x925a4bb6aaa0bc3485e4e48558dfaa370d02c2985f62955d26c0f47cfd56cc2f', 'reason': 'Storage limit reached', 'message': 'revert'}}

# %%
total_records = contract.functions.getTotalRecords().call()
print(f"Total IoT records stored: {total_records}")
# Out:
# Total IoT records stored: 100

# %%
record = contract.functions.getRecord(0).call()
print("First Stored Record:", record)
# Out:
# First Stored Record: [1750758464, 'PAT573', 'heart_rate', '98']

# %%
import pandas as pd


# Retrieve all IoT records
data = []
for i in range(total_records):
    record = contract.functions.getRecord(i).call()
    data.append({
        "timestamp": record[0],
        "device_id": record[1],
        "data_type": record[2],
        "data_value": record[3]
    })


# Convert to a DataFrame
df = pd.DataFrame(data)

# Convert timestamp to readable format
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")

df["numeric_value"] = df["data_value"].str.extract(r'(\d+\.?\d*)').astype(float)

df.fillna(0, inplace=True)

# Display first few records
print(df.head())
# Out:
#             timestamp device_id       data_type data_value  numeric_value
# 0 2025-06-24 09:47:44    PAT573      heart_rate         98           98.0
# 1 2025-06-24 09:47:44    PAT573  blood_pressure     105/75          105.0
# 2 2025-06-24 09:47:44    PAT573    oxygen_level         95           95.0
# 3 2025-06-24 09:47:44    PAT573       body_temp       36.6           36.6
# 4 2025-06-24 09:47:45    PAT472      heart_rate         93           93.0

# %%
df.to_csv("cleaned_iot_data.csv", index=False)
print("✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv")
# Out:
# ✅ Cleaned IoT data saved successfully as cleaned_iot_data.csv
